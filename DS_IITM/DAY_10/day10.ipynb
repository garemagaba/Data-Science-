# %%
#NumPy To be continued...

# hstack
# vstack
# mean
# median
# where
# clip
# Broadcasting

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr = plt.imread(r'''C:\Users\HP\Pictures\Camera Roll\download.jfif''')

# %%
plt.imshow(arr)

# %%
arr.shape
# Out:
# (490, 736, 3)

# %%
arr = arr.copy()

# %%
plt.imshow(arr)

# %%
a = np.random.randint(0,255,(50,50,3)) #last 3 refers to channels 
plt.imshow(a)

# %%
#while True:
    #import numpy as np
    #import matplotlib.pyplot as plt
    #import time
    #a = np.random.randint(0,255,(5,5,3))
    #plt.imshow(a)
    #plt.show()
    #time.sleep(0.3)
    #display(clear = True) #to clear the previous result/ output

# %%
a = np.random.randint(0,255,(4,4,3))
a
# Out:
# array([[[153, 144, 177],
#         [112, 254, 229],
#         [109, 123, 245],
#         [147, 134, 204]],
#
#        [[241, 151,  90],
#         [192,  63, 227],
#         [111,  37, 248],
#         [ 68, 232,  44]],
#
#        [[137,  49,  65],
#         [ 49,  27, 248],
#         [ 25, 187, 200],
#         [190,  72,  46]],
#
#        [[ 34, 103, 236],
#         [249,  62, 200],
#         [ 10, 177, 118],
#         [ 98,  85,  54]]], dtype=int32)

# %%
final_ar = np.split(a,2)
len(final_ar)
# Out:
# 2

# %%
plt.imshow(a)

# %%
plt.imshow(final_ar[1])

# %%
np.split(a,2,axis = 1)
# Out:
# [array([[[153, 144, 177],
#          [112, 254, 229]],
#
#         [[241, 151,  90],
#          [192,  63, 227]],
#
#         [[137,  49,  65],
#          [ 49,  27, 248]],
#
#         [[ 34, 103, 236],
#          [249,  62, 200]]], dtype=int32),
#  array([[[109, 123, 245],
#          [147, 134, 204]],
#
#         [[111,  37, 248],
#          [ 68, 232,  44]],
#
#         [[ 25, 187, 200],
#          [190,  72,  46]],
#
#         [[ 10, 177, 118],
#          [ 98,  85,  54]]], dtype=int32)]

# %%
ar_part3 = np.split(a,3, axis = 2)

# %%
plt.imshow(a)

# %%
len(ar_part3)
# Out:
# 3

# %%
plt.imshow(ar_part3[0])

# %%
arr.shape
# Out:
# (490, 736, 3)

# %%
plt.imshow(np.split(arr,3,axis = 2)[0])

# %%
plt.imshow(np.split(arr,3,axis = 2)[1])

# %%
plt.imshow(np.split(arr,3,axis = 2)[2])

# %%
plt.imshow(np.split(arr,2,axis = 0)[0])

# %%
plt.imshow(np.split(arr,2,axis = 0)[1])

# %%
plt.imshow(np.split(arr,2,axis =1 )[1])

# %%
plt.imshow(arr)

# %%
arr.shape
# Out:
# (490, 736, 3)

# %%
736//3
# Out:
# 245

# %%
plt.imshow(arr[:,:245,:])

# %%
plt.imshow(arr[:,245:245*2,:])

# %%
plt.imshow(arr[:,245*2:,:])

# %%
array = np.random.randint(1,500,(4,4))
array
# Out:
# array([[311, 410, 241, 202],
#        [206,  68, 451, 107],
#        [136, 492, 442, 338],
#        [ 44, 198, 372,  15]], dtype=int32)

# %%
np.where(array>200)  #it'll pass to check the condition
# Out:
# (array([0, 0, 0, 0, 1, 1, 2, 2, 2, 3]), array([0, 1, 2, 3, 0, 2, 1, 2, 3, 2]))

# %%
np.where(array>200,'High Sales','Low Sales')
# Out:
# array([['High Sales', 'High Sales', 'High Sales', 'High Sales'],
#        ['High Sales', 'Low Sales', 'High Sales', 'Low Sales'],
#        ['Low Sales', 'High Sales', 'High Sales', 'High Sales'],
#        ['Low Sales', 'Low Sales', 'High Sales', 'Low Sales']],
#       dtype='<U10')

# %%
np.where(array>200,'High Sales',array)
# Out:
# array([['High Sales', 'High Sales', 'High Sales', 'High Sales'],
#        ['High Sales', '68', 'High Sales', '107'],
#        ['136', 'High Sales', 'High Sales', 'High Sales'],
#        ['44', '198', 'High Sales', '15']], dtype='<U11')

# %%
np.clip(array,100,250) #outliner remove/replace = only the numbers that are upper or lower than the range will change, the numbers within the range remains the same
# Out:
# array([[250, 250, 241, 202],
#        [206, 100, 250, 107],
#        [136, 250, 250, 250],
#        [100, 198, 250, 100]], dtype=int32)

# %%
#Broadcasting!! IMPORTANT:  mismatch of shape can cause error, it can still work with dimensions 

a = np.random.randint(1,10,7)
b = np.random.randint(1,10,(2,7))

print(a)
print('------\n\n')
print(b)
# Out:
# [9 3 6 2 2 2 9]
# ------
#
#
# [[1 2 6 1 7 6 7]
#  [6 6 4 6 7 3 5]]

# %%
a + b
# Out:
# array([[10,  5, 12,  3,  9,  8, 16],
#        [15,  9, 10,  8,  9,  5, 14]], dtype=int32)

# %%
a * b
# Out:
# array([[ 9,  6, 36,  2, 14, 12, 63],
#        [54, 18, 24, 12, 14,  6, 45]], dtype=int32)

# %%
a = np.random.randint(1,10,(4,1))
b = np.random.randint(1,10,(1,4))

print(a)
print('------\n\n')
print(b)
# Out:
# [[6]
#  [4]
#  [8]
#  [3]]
# ------
#
#
# [[3 8 1 9]]

# %%
a + b
# Out:
# array([[ 9, 14,  7, 15],
#        [ 7, 12,  5, 13],
#        [11, 16,  9, 17],
#        [ 6, 11,  4, 12]], dtype=int32)

# %%
#Introduction to Pandas!!

#ds - data: exploratory data analysis(EDA)
#EDA - excel, powerbi, sql, python

#pandas : panel data frame - data in structured form

#data explore: report(insights)
#report>> data scientist

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.3'

# %%
import random
products = ['Chair','Table','Laptop','Mobile','Charger']
regions = ['east','west','north','south']
all_date = pd.date_range('01-01-2025','23-07-2025')

data = {'Order_Id': range(1,1001),
        'Date':random.choices(all_date, k = 1000),
       'Region Name': random.choices(regions, k = 1000),
       'Product Name': random.choices(products, k = 1000),
       'Sales': np.random.randint(100,10000,1000),
       'Qty': np.random.randint(1,10,1000),
       'Profit': np.random.randint(-10000,10000,1000)}

table = pd.DataFrame(data)
table
# Out:
#      Order_Id       Date Region Name Product Name  Sales  Qty  Profit
# 0           1 2025-04-03       south       Laptop   5740    1   -5475
# 1           2 2025-05-15       north        Table   1997    5   -7551
# 2           3 2025-03-24       south        Chair   4783    6   -6371
# 3           4 2025-01-08        west       Mobile    957    4   -7600
# 4           5 2025-05-10       south        Chair   2297    1   -3508
# ..        ...        ...         ...          ...    ...  ...     ...
# 995       996 2025-03-06        east      Charger   8962    7    -157
# 996       997 2025-07-12        west       Mobile   6154    5    4610
# 997       998 2025-07-10       south       Mobile   5139    5    1188
# 998       999 2025-05-07       north        Chair   3633    3   -1562
# 999      1000 2025-03-08       south        Table   5633    3   -4568
#
# [1000 rows x 7 columns]

# %%
#data column

# %%
#top data
#by default shows first 5 elements
table.head(10)
# Out:
#    Order_Id       Date Region Name Product Name  Sales  Qty  Profit
# 0         1 2025-04-03       south       Laptop   5740    1   -5475
# 1         2 2025-05-15       north        Table   1997    5   -7551
# 2         3 2025-03-24       south        Chair   4783    6   -6371
# 3         4 2025-01-08        west       Mobile    957    4   -7600
# 4         5 2025-05-10       south        Chair   2297    1   -3508
# 5         6 2025-03-25       south      Charger   2529    1   -1734
# 6         7 2025-02-13        east        Table   1582    2   -1365
# 7         8 2025-04-23       north      Charger   1991    1   -5812
# 8         9 2025-02-11        west       Mobile   9643    4    8603
# 9        10 2025-01-26       south      Charger   2798    1   -6568

# %%
#bottom data 
#by default shows first 5 elements
table.tail()
# Out:
#      Order_Id       Date Region Name Product Name  Sales  Qty  Profit
# 995       996 2025-03-06        east      Charger   8962    7    -157
# 996       997 2025-07-12        west       Mobile   6154    5    4610
# 997       998 2025-07-10       south       Mobile   5139    5    1188
# 998       999 2025-05-07       north        Chair   3633    3   -1562
# 999      1000 2025-03-08       south        Table   5633    3   -4568

# %%
#for sample data
#by default shows first element
table.sample()
# Out:
#      Order_Id       Date Region Name Product Name  Sales  Qty  Profit
# 408       409 2025-04-14       south      Charger    768    3   -1782

# %%
#For Table Information
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order_Id      1000 non-null   int64
#  1   Date          1000 non-null   datetime64[ns]
#  2   Region Name   1000 non-null   object
#  3   Product Name  1000 non-null   object
#  4   Sales         1000 non-null   int32
#  5   Qty           1000 non-null   int32
#  6   Profit        1000 non-null   int32
# dtypes: datetime64[ns](1), int32(3), int64(1), object(2)
# memory usage: 43.1+ KB

# %%
#Pandas Datatypes:
#DataFrame
#Series

# %%
#column name
table.columns
# Out:
# Index(['Order_Id', 'Date', 'Region Name', 'Product Name', 'Sales', 'Qty',
#        'Profit'],
#       dtype='object')

# %%
#index
table.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
#To check NAN values:
table.isna()
# Out:
#      Order_Id   Date  Region Name  Product Name  Sales    Qty  Profit
# 0       False  False        False         False  False  False   False
# 1       False  False        False         False  False  False   False
# 2       False  False        False         False  False  False   False
# 3       False  False        False         False  False  False   False
# 4       False  False        False         False  False  False   False
# ..        ...    ...          ...           ...    ...    ...     ...
# 995     False  False        False         False  False  False   False
# 996     False  False        False         False  False  False   False
# 997     False  False        False         False  False  False   False
# 998     False  False        False         False  False  False   False
# 999     False  False        False         False  False  False   False
#
# [1000 rows x 7 columns]

# %%
table.isna().value_counts()   #value_counts() - checks present element of given table
# Out:
# Order_Id  Date   Region Name  Product Name  Sales  Qty    Profit
# False     False  False        False         False  False  False     1000
# Name: count, dtype: int64

# %%
table.isnull().value_counts()  #isnull another method
